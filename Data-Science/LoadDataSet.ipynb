# %% [markdown]
# # Load Dataset From Seaborn

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'c:\users\shourov\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns # import Seaborn
sns.set() # Apply the default seaborn theme, scaling, and color palette

# %% [markdown]
# #### Here I load titanic dataset from seaborn and strore the dataset in titanic variable

# %%
titanic = sns.load_dataset('titanic')  # Load Dataset and store in a variable

# %% [markdown]
# #### Now I show data

# %%
titanic # Call that variable
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## In above cell we see the data for show data, here I just call that variable. If you remember I used a variable to store the dataset
